# %% [markdown]
# 1.(a)Import the amazon.csv dataset into a Pandas DataFrame

# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\san\Documents\\amazon.csv')
print(df)
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# (b)Display the first few rows and understand the data structure.

# %%
print(df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.isnull()
# Out:
#       product_id  product_name  category  discounted_price  actual_price  \
# 0          False         False     False             False         False
# 1          False         False     False             False         False
# 2          False         False     False             False         False
# 3          False         False     False             False         False
# 4          False         False     False             False         False
# ...          ...           ...       ...               ...           ...
# 1460       False         False     False             False         False
# 1461       False         False     False             False         False
# 1462       False         False     False             False         False
# 1463       False         False     False             False         False
# 1464       False         False     False             False         False
#
#       discount_percentage  rating  rating_count  about_product  user_id  \
# ...

# %%
## Check for missing values in each column
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Check for total missing values in the DataFrame
total_missing_values=df.isnull().sum().sum()
print("\nTotal missing values:", total_missing_values)
# Out:
# Total missing values: 2

# %%
# Display the rows with missing values
rows_with_missing = df[df.isnull().any(axis=1)]
print("\nRows with missing values:\n", rows_with_missing)
# Out:
# Rows with missing values:
#       product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 324  Computers&Accessories|Accessories&Peripherals|...             ₹249
#
#     actual_price discount_percentage rating rating_count  \
# 282         ₹999                 80%    3.0          NaN
# 324         ₹999                 75%    5.0          NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# ...

# %%
# Drop rows with any missing values
df_dropped_rows = df.dropna()
print("\nDataFrame after dropping rows with missing values:\n", df_dropped_rows)
# Out:
# DataFrame after dropping rows with missing values:
#        product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# ...

# %%
#Drop columns with any missing values.
df_dropped_columns = df.dropna(axis=1)
print("\nDataFrame after dropping columns with missing values:\n", df_dropped_columns)
# Out:
# DataFrame after dropping columns with missing values:
#        product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# ...

# %% [markdown]
# 2. Data Cleaning
# (a) Convert price-related columns (discounted_price, actual_price) to
# numerical format.

# %%
df['discounted_price'] = pd.to_numeric(df['discounted_price'].astype(str).str.replace('[₹,]', '', regex=True), errors='coerce')
df['actual_price'] = pd.to_numeric(df['actual_price'].astype(str).str.replace('[₹,]', '', regex=True), errors='coerce')
print(df[['discounted_price', 'actual_price']].dtypes)
print (df)
# Out:
# discounted_price    float64
# actual_price        float64
# dtype: object
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# ...

# %%
print(df)
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %% [markdown]
# 2(b)Convert rating_count to integer values (remove commas if present).

# %%
print (df.head)
# Out:
# <bound method NDFrame.head of       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# ...

# %%
def remove_commas(value):
    if isinstance(value, str):
        return value.replace(',', '')
    return value

df['rating_count'] = df['rating_count'].apply(remove_commas)
df['rating_count'] = pd.to_numeric(df['rating_count'], errors='coerce').astype('Int64')

print(df['rating_count'].dtypes)
# Out:
# Int64

# %% [markdown]
# 2(c)Extract relevant product categories from category column.

# %%
def get_main_category(categories):
    try:
        return eval(categories)[0]['name']
    except:
        return None

df['main_category'] = df['category'].apply(get_main_category)

print(df[['category', 'main_category']].head())
# Out:
#                                             category main_category
# 0  Computers&Accessories|Accessories&Peripherals|...          None
# 1  Computers&Accessories|Accessories&Peripherals|...          None
# 2  Computers&Accessories|Accessories&Peripherals|...          None
# 3  Computers&Accessories|Accessories&Peripherals|...          None
# 4  Computers&Accessories|Accessories&Peripherals|...          None

# %% [markdown]
# 3.(a)Create a new column for discount_amount (actual_price -
# discounted_price).

# %%
df['discounted_price'] = pd.to_numeric(df['discounted_price'].astype(str).str.replace('[₹,]', '', regex=True), errors='coerce')
df['actual_price'] = pd.to_numeric(df['actual_price'].astype(str).str.replace('[₹,]', '', regex=True), errors='coerce')

df['discount_amount'] = df['actual_price'] - df['discounted_price']

print(df[['actual_price', 'discounted_price', 'discount_amount']].head())
print(df)
# Out:
#    actual_price  discounted_price  discount_amount
# 0        1099.0             399.0            700.0
# 1         349.0             199.0            150.0
# 2        1899.0             199.0           1700.0
# 3         699.0             329.0            370.0
# 4         399.0             154.0            245.0
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# ...

# %% [markdown]
# 3 b.Convert discount_percentage into a numeric value.

# %%
df['discount_percentage'] = pd.to_numeric(df['discount_percentage'].str.replace('%', '', regex=False), errors='coerce')
print(df['discount_percentage'].dtypes)  
print(df.head())
# Out:
# int64
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage rating  rating_count  \
# 0        1099.0                   64    4.2         24269
# ...

# %%
print(df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage rating  rating_count  \
# 0        1099.0                   64    4.2         24269
# ...

# %% [markdown]
# 3(c)Extract the year of reviews if a timestamp is present.

# %%
def extract_year(timestamp):
    """Extracts the year from a timestamp string."""
    try:
        # Attempt to parse common timestamp formats
        dt = datetime.fromisoformat(timestamp.replace('Z', '+00:00')) # Handles ISO format
        return dt.year
    except ValueError:
        try:
            # Attempt to parse common string formats
            dt = datetime.strptime(timestamp, "%Y-%m-%d %H:%M:%S")
            return dt.year
        except ValueError:
            try:
                # Attempt to parse another common string format
                dt = datetime.strptime(timestamp, "%m/%d/%Y %H:%M:%S")
                return dt.year
            except ValueError:
                try:
                    # Attempt to parse unix timestamp
                    dt = datetime.fromtimestamp(int(timestamp))
                    return dt.year
                except ValueError:
                    return None # Return None if parsing fails
                print(timestamps)  # Or print(df['timestamp']) for Pandas

# %%
import pandas as pd
import re

try:
    df = pd.read_csv('Amazon.csv')
    df['review_year'] = df['reviews'].astype(str).apply(lambda x: int(re.search(r'\d{4}', x).group(0)) if re.search(r'\d{4}', x) else None)
    print(df[['reviews', 'review_year']].head())
except FileNotFoundError:
    print("File not found")
except:
    print("An error occurred")
# Out:
# An error occurred

# %%
amazon_data=pd.read_csv("updated_data.csv")
amazon_data.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
import pandas as pd
df = pd.read_csv("updated_data.csv")

df['discounted_price'] = df['discounted_price'].astype(str).str.replace('[₹,]', '', regex=True)
df['actual_price'] = df['actual_price'].astype(str).str.replace('[₹,]', '', regex=True)

df.to_csv ('C:\\Users\\san\\Desktop\\amazon dataset\\updated_data.csv, index=False')  # Overwrite the original CSV

# %%
print(df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...            399.0
# 1  Computers&Accessories|Accessories&Peripherals|...            199.0
# 2  Computers&Accessories|Accessories&Peripherals|...            199.0
# 3  Computers&Accessories|Accessories&Peripherals|...            329.0
# 4  Computers&Accessories|Accessories&Peripherals|...            154.0
#
#   actual_price discount_percentage rating rating_count  \
# 0       1099.0                 64%    4.2       24,269
# ...

# %%
import mysql.connector
import matplotlib.pyplot as plt

try:
    mydb = mysql.connector.connect(host="localhost", user="root", password="munene2024", database="ecommerce_db")
    mycursor = mydb.cursor()
    mycursor.execute("SELECT rating, COUNT(*) FROM products GROUP BY rating ORDER BY rating")
    ratings, counts = zip(*mycursor.fetchall())
    plt.bar(ratings, counts); plt.show()
except Exception as e:
    print(f"Error: {e}")
finally:w
    if 'mydb' in locals() and mydb.is_connected(): mydb.close()

# %%
import mysql.connector
import pandas as pd

try:
    df = pd.read_sql("SELECT discount_percentage, rating FROM products", mysql.connector.connect(host="localhost", user="root", password="munene2024", database="ecommerce_db"))
    df['discount_percentage'] = pd.to_numeric(df['discount_percentage'].str.replace('%', '').str.replace('|', ''), errors='coerce')
    print(df['discount_percentage'].corr(df['rating']))
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: could not convert string to float: '|'
# C:\Users\san\AppData\Local\Temp\ipykernel_13612\570416175.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT discount_percentage, rating FROM products", mysql.connector.connect(host="localhost", user="root", password="munene2024", database="ecommerce_db"))

# %%
import mysql.connector
import pandas as pd
import re

try:
    mydb = mysql.connector.connect(host="localhost", user="root", password="munene2024", database="ecommerce_db")
    df = pd.read_sql("SELECT discount_percentage, rating FROM products", mydb)

    # Use regular expressions to remove non-numeric characters
    df['discount_percentage'] = pd.to_numeric(df['discount_percentage'].str.replace(r'[^\d\.]', '', regex=True), errors='coerce')

    print(df['discount_percentage'].corr(df['rating']))

except Exception as e:
    print(f"Error: {e}")
finally:
    if 'mydb' in locals() and mydb.is_connected():
        mydb.close()
# Out:
# Error: could not convert string to float: '|'
# C:\Users\san\AppData\Local\Temp\ipykernel_13612\1184793577.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT discount_percentage, rating FROM products", mydb)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import mysql.connector

# MySQL database connection details
db_config = {
    'host': 'localhost',  # e.g., 'localhost'
    'user': 'root',
    'password': 'munene2024',
    'database': 'ecommerce_db'
}

try:
    # Establish a connection to the MySQL database
    connection = mysql.connector.connect(**db_config)
    cursor = connection.cursor()

    # SQL query to retrieve top 10 highest-rated products
    query = """
    SELECT product_name, CAST(rating AS DECIMAL(3, 2)) AS rating_value
    FROM products
    ORDER BY rating_value DESC
    LIMIT 10;
    """

    # Execute the query
    cursor.execute(query)

    # Fetch the results
    results = cursor.fetchall()

    # Convert the results to a Pandas DataFrame
    df = pd.DataFrame(results, columns=['product_name', 'rating_value'])

    # Create the bar chart
    plt.figure(figsize=(12, 6))  # Adjust figure size as needed
    plt.bar(df['product_name'], df['rating_value'])
    plt.xlabel('Product Name')
    plt.ylabel('Rating')
    plt.title('Top 10 Highest-Rated Products')
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
    plt.tight_layout()
    plt.show()

except mysql.connector.Error as err:
    print(f"Error: {err}")

finally:
    # Close the cursor and connection
    if connection.is_connected():
        cursor.close()
        connection.close()
# Out:
# C:\Users\san\AppData\Local\Temp\ipykernel_13612\3805817276.py:42: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine

db_config = {'host': 'localhost', 'user': 'root', 'password': 'munene2024', 'database': 'ecommerce_db'}

try:
    # Create SQLAlchemy engine
    engine = create_engine(f"mysql+mysqlconnector://{db_config['user']}:{db_config['password']}@{db_config['host']}/{db_config['database']}")

    # Read data using pd.read_sql with the engine
    df = pd.read_sql("SELECT discount_percentage, rating FROM products", engine)

    # Convert columns to numeric, handling errors
    df[['discount_percentage', 'rating']] = df[['discount_percentage', 'rating']].apply(pd.to_numeric, errors='coerce').dropna()

    if not df.empty:
        plt.scatter(df['discount_percentage'], df['rating'])
        plt.xlabel('Discount %')
        plt.ylabel('Rating')
        plt.title('Discount % vs. Rating')
        plt.grid(True)
        plt.show()
    else:
        print("No data to plot.")

except Exception as err:
    print(f"Error: {err}")
    plot_scatter(df)

# %%
import mysql.connector
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine

db_config = {'host': 'localhost', 'user': 'root', 'password': 'munene2024', 'database': 'ecommerce_db'}

try:
    engine = create_engine(f"mysql+mysqlconnector://{db_config['user']}:{db_config['password']}@{db_config['host']}/{db_config['database']}")
    df = pd.read_sql("SELECT category FROM products", engine)

    category_counts = df['category'].value_counts()

    plt.figure(figsize=(8, 8))
    plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
    plt.title('Top-Selling Categories (by Count)')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

except Exception as err:
    print(f"Error: {err}")

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sqlalchemy import create_engine

db_config = {'host': 'localhost', 'user': 'root', 'password': 'munene2024', 'database': 'ecommerce_db'}

try:
    engine = create_engine(f"mysql+mysqlconnector://{db_config['user']}:{db_config['password']}@{db_config['host']}/{db_config['database']}")
    df = pd.read_sql("SELECT discounted_price, actual_price, discount_percentage, rating, rating_count FROM products", engine)

    # Convert columns to numeric, handling errors
    df = df.apply(pd.to_numeric, errors='coerce').dropna()

    # Calculate correlation matrix
    correlation_matrix = df.corr()

    # Create heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title('Correlation Heatmap')
    plt.show()

except Exception as err:
    print(f"Error: {err}")
# Out:
# C:\Users\san\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\san\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
